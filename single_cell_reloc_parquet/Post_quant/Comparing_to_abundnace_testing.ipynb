# %%
import pandas as pd
import os
import statistics
import numpy as np
#Todo:convert this file into function form so that it is callable

# %%
# Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/Code/Data_copies/Information_files/Abundance_Mod_Stress.xlsx", sheet_name="Table S8")
Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/ProteinAbundance-main/supplementalTables/TableS8_Final_Mod.xlsx", sheet_name="Table S8")

Localization_information = pd.read_parquet("D:/Microfluidics/Most_final_collected/Most_final_collected/Combined_by_perc/Col_with_Abund/Merged/Final_wAbundLocal.parquet")
# Out:
# c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
Abundance_information
# Out:
#      Table S8. Protein abundance in molecules per cell in stress conditions.  \
# 0                                                   NaN
# 1                                       Systematic Name
# 2                                                   NaN
# 3                                               YGL048C
# 4                                               YNL241C
# ...                                                 ...
# 5856                                            YPR200C
# 5857                                            YPR201W
# 5858                                            YPR202W
# 5859                                            YPR203W
# 5860                                            YPR204W
#
#          Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1     Standard Name           DEN           NaN           MAZ           NaN
# 2               NaN     Untreated         MMS g     Untreated         MMS h
# 3              RPT6  17419.838579  41737.573479  20979.296888  36484.391086
# 4              ZWF1  10218.005038  18123.566822  10959.523235  21988.602333
# ...             ...           ...           ...           ...           ...
# 5856           ARR2           NaN           NaN           NaN           NaN
# 5857           ARR3           NaN           NaN           NaN           NaN
# 5858        YPR202W           NaN           NaN           NaN           NaN
# 5859        YPR203W           NaN           NaN           NaN           NaN
# 5860        YPR204W           NaN           NaN           NaN           NaN
#
#         Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9   Unnamed: 10
# 0              NaN           NaN           NaN           NaN           NaN
# 1              LEE           NaN           TKA           NaN           NaN
# 2        Untreated         MMS i     Untreated          HU j         MMS k
# 3     19271.478356  51447.640409  20544.515731  30972.401953  46261.659363
# 4      8886.818657  20054.903918  12464.813162  20504.878179  23851.836531
# ...            ...           ...           ...           ...           ...
# 5856           NaN           NaN           NaN           NaN           NaN
# 5857           NaN           NaN           NaN           NaN           NaN
# 5858           NaN           NaN           NaN           NaN           NaN
# 5859           NaN           NaN           NaN           NaN           NaN
# 5860           NaN           NaN           NaN           NaN           NaN
#
# [5861 rows x 11 columns]

# %%
# Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/Code/Data_copies/Information_files/Abundance_Mod_Stress.xlsx", sheet_name="Table S8")
Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/ProteinAbundance-main/supplementalTables/TableS8_Final_Mod.xlsx", sheet_name="Table S8")
Localization_information = pd.read_parquet("D:/Microfluidics/Most_final_collected/Most_final_collected/Combined_by_perc/Col_with_Abund/Merged/Final_wAbundLocal.parquet")
# Out:
# c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
Abundance_information
# Out:
#      Systematic Name Standard Name           DEN     Unnamed: 3           MAZ  \
# 0                NaN           NaN     Untreated          MMS g     Untreated
# 1            YGL048C          RPT6  17419.838579   41737.573479  20979.296888
# 2            YNL241C          ZWF1  10218.005038   18123.566822  10959.523235
# 3            YMR173W         DDR48   8150.522802   55681.295155  25208.053561
# 4            YGR209C          TRX2  38450.827723  247092.923816  38256.981659
# ...              ...           ...           ...            ...           ...
# 5854         YPR200C          ARR2           NaN            NaN           NaN
# 5855         YPR201W          ARR3           NaN            NaN           NaN
# 5856         YPR202W       YPR202W           NaN            NaN           NaN
# 5857         YPR203W       YPR203W           NaN            NaN           NaN
# 5858         YPR204W       YPR204W           NaN            NaN           NaN
#
#          Unnamed: 5           LEE     Unnamed: 7           TKA    Unnamed: 9  \
# 0             MMS h     Untreated          MMS i     Untreated          HU j
# 1      36484.391086  19271.478356   51447.640409  20544.515731  30972.401953
# 2      21988.602333   8886.818657   20054.903918  12464.813162  20504.878179
# 3      44188.081847   9343.855316   44258.563122  10128.228613  17898.276875
# 4     159340.730951  46601.624833  187922.589878  31164.954467  62077.373938
# ...             ...           ...            ...           ...           ...
# 5854            NaN           NaN            NaN           NaN           NaN
# 5855            NaN           NaN            NaN           NaN           NaN
# 5856            NaN           NaN            NaN           NaN           NaN
# 5857            NaN           NaN            NaN           NaN           NaN
# 5858            NaN           NaN            NaN           NaN           NaN
#
#         Unnamed: 10
# 0             MMS k
# 1      46261.659363
# 2      23851.836531
# 3      44459.761676
# 4     280083.125042
# ...             ...
# 5854            NaN
# 5855            NaN
# 5856            NaN
# 5857            NaN
# 5858            NaN
#
# [5859 rows x 11 columns]

# %%
# Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/Code/Data_copies/Information_files/Abundance_Mod_Stress.xlsx", sheet_name="Table S8")
Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/ProteinAbundance-main/supplementalTables/TableS8_Final_Mod.xlsx", engine='openpyxl')
# Localization_information = pd.read_parquet("D:/Microfluidics/Most_final_collected/Most_final_collected/Combined_by_perc/Col_with_Abund/Merged/Final_wAbundLocal.parquet")
# Out:
# c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
Abundance_information
# Out:
#      Systematic Name Standard Name           DEN     Unnamed: 3           MAZ  \
# 0                NaN           NaN     Untreated          MMS g     Untreated
# 1            YGL048C          RPT6  17419.838579   41737.573479  20979.296888
# 2            YNL241C          ZWF1  10218.005038   18123.566822  10959.523235
# 3            YMR173W         DDR48   8150.522802   55681.295155  25208.053561
# 4            YGR209C          TRX2  38450.827723  247092.923816  38256.981659
# ...              ...           ...           ...            ...           ...
# 5854         YPR200C          ARR2           NaN            NaN           NaN
# 5855         YPR201W          ARR3           NaN            NaN           NaN
# 5856         YPR202W       YPR202W           NaN            NaN           NaN
# 5857         YPR203W       YPR203W           NaN            NaN           NaN
# 5858         YPR204W       YPR204W           NaN            NaN           NaN
#
#          Unnamed: 5           LEE     Unnamed: 7           TKA    Unnamed: 9  \
# 0             MMS h     Untreated          MMS i     Untreated          HU j
# 1      36484.391086  19271.478356   51447.640409  20544.515731  30972.401953
# 2      21988.602333   8886.818657   20054.903918  12464.813162  20504.878179
# 3      44188.081847   9343.855316   44258.563122  10128.228613  17898.276875
# 4     159340.730951  46601.624833  187922.589878  31164.954467  62077.373938
# ...             ...           ...            ...           ...           ...
# 5854            NaN           NaN            NaN           NaN           NaN
# 5855            NaN           NaN            NaN           NaN           NaN
# 5856            NaN           NaN            NaN           NaN           NaN
# 5857            NaN           NaN            NaN           NaN           NaN
# 5858            NaN           NaN            NaN           NaN           NaN
#
#         Unnamed: 10
# 0             MMS k
# 1      46261.659363
# 2      23851.836531
# 3      44459.761676
# 4     280083.125042
# ...             ...
# 5854            NaN
# 5855            NaN
# 5856            NaN
# 5857            NaN
# 5858            NaN
#
# [5859 rows x 11 columns]

# %%
# Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/Code/Data_copies/Information_files/Abundance_Mod_Stress.xlsx", sheet_name="Table S8")
Abundance_information = pd.read_excel("C:/Users/pcnba/Grant Brown's Lab Dropbox/Peter Bartlett/Peter Bartlett Data/ProteinAbundance-main/supplementalTables/TableS8_Final_Mod.xlsx", engine='openpyxl')
# Localization_information = pd.read_parquet("D:/Microfluidics/Most_final_collected/Most_final_collected/Combined_by_perc/Col_with_Abund/Merged/Final_wAbundLocal.parquet")
# Out:
# c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
Abundance_information
# Out:
#      Systematic Name Standard Name  DEN_Untreated        DEN_MMS  \
# 0            YGL048C          RPT6   17419.838579   41737.573479
# 1            YNL241C          ZWF1   10218.005038   18123.566822
# 2            YMR173W         DDR48    8150.522802   55681.295155
# 3            YGR209C          TRX2   38450.827723  247092.923816
# 4            YJR104C          SOD1   76309.695711  184379.227046
# ...              ...           ...            ...            ...
# 5853         YPR200C          ARR2            NaN            NaN
# 5854         YPR201W          ARR3            NaN            NaN
# 5855         YPR202W       YPR202W            NaN            NaN
# 5856         YPR203W       YPR203W            NaN            NaN
# 5857         YPR204W       YPR204W            NaN            NaN
#
#       MAZ_Untreated        MAZ_MMS  LEE_Untreated        LEE_MMS  \
# 0      20979.296888   36484.391086   19271.478356   51447.640409
# 1      10959.523235   21988.602333    8886.818657   20054.903918
# 2      25208.053561   44188.081847    9343.855316   44258.563122
# 3      38256.981659  159340.730951   46601.624833  187922.589878
# 4      97567.638218  264187.927070  116660.737926  277299.190013
# ...             ...            ...            ...            ...
# 5853            NaN            NaN            NaN            NaN
# 5854            NaN            NaN            NaN            NaN
# 5855            NaN            NaN            NaN            NaN
# 5856            NaN            NaN            NaN            NaN
# 5857            NaN            NaN            NaN            NaN
#
#       TKA_Untreated        TKA_MMS
# 0      20544.515731   46261.659363
# 1      12464.813162   23851.836531
# 2      10128.228613   44459.761676
# 3      31164.954467  280083.125042
# 4      71966.948045  228028.982588
# ...             ...            ...
# 5853            NaN            NaN
# 5854            NaN            NaN
# 5855            NaN            NaN
# 5856            NaN            NaN
# 5857            NaN            NaN
#
# [5858 rows x 10 columns]

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  mKO_RAWfactor_lower  \
# 0.0                                   1.223077  ...                  NaN
# 1.0                                   1.264146  ...                  NaN
# 2.0                                   1.181520  ...                  NaN
# 3.0                                   1.246377  ...                  NaN
# 4.0                                   1.251969  ...                  NaN
# ...                                        ...  ...                  ...
# 7571823.0                             1.192308  ...                  NaN
# 7571824.0                             1.191077  ...                  NaN
# 7571825.0                             1.178295  ...                  NaN
# 7571826.0                             1.214000  ...                  NaN
# 7571827.0                             1.175344  ...                  NaN
#
#            <lambda_0>_y  count  Abundance  z_score_Loc  z_score_Abund  \
# 0.0            0.029878  127.0   4.867534    -0.799651      -0.620910
# 1.0            0.029878  127.0   4.812184    -0.193858      -1.030582
# 2.0            0.029878  127.0   4.828314     0.349437      -0.911201
# 3.0            0.029878  127.0   4.927254    -0.661603      -0.178900
# 4.0            0.029878  127.0   4.844187    -0.514413      -0.793715
# ...                 ...    ...        ...          ...            ...
# 7571823.0      0.012615  159.0   4.867534    -0.089417       0.014743
# 7571824.0      0.012615  159.0   4.867534    -0.528462       0.014743
# 7571825.0      0.012615  159.0   4.859812     0.051342      -0.224311
# 7571826.0      0.012615  159.0   4.867534    -0.421331       0.014743
# 7571827.0      0.012615  159.0   4.875197    -0.351662       0.251966
#
#            Pearson_coeff_Loc_Abund  Signif_corr_Loc_Abund  Systematic ORF  \
# 0.0                       0.125106               0.161081            None
# 1.0                       0.125106               0.161081            None
# 2.0                       0.125106               0.161081            None
# 3.0                       0.125106               0.161081            None
# 4.0                       0.125106               0.161081            None
# ...                            ...                    ...             ...
# 7571823.0                 0.052237               0.513151            None
# 7571824.0                 0.052237               0.513151            None
# 7571825.0                 0.052237               0.513151            None
# 7571826.0                 0.052237               0.513151            None
# 7571827.0                 0.052237               0.513151            None
#
#            Location_simplfied
# 0.0                      None
# 1.0                      None
# 2.0                      None
# 3.0                      None
# 4.0                      None
# ...                       ...
# 7571823.0                None
# 7571824.0                None
# 7571825.0                None
# 7571826.0                None
# 7571827.0                None
#
# [7571828 rows x 90 columns]

# %%
merged.dropna(subset=['MMS_Mean'], inplace= True)
merged.drop(merged.columns[merged.columns.str.contains('Unnamed',case = False)],axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pcnba\Grant Brown's Lab Dropbox\Peter Bartlett\Peter Bartlett Data\Code\single_cell_reloc\single_cell_reloc_parquet\Post_quant\Comparing_to_abundnace.py in line 3
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=44'>45</a> breakpoint()
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=45'>46</a> #%%
# ----> <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=46'>47</a> merged.dropna(subset=['MMS_Mean'], inplace= True)
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=47'>48</a> merged.drop(merged.columns[merged.columns.str.contains('Unnamed',case = False)],axis = 1, inplace = True)
#
# NameError: name 'merged' is not defined

# %%
#* Group cells by the strain frame
Localization_information['Strain_frame'] = Localization_information['ImageID'] + Localization_information['Protein']

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  <lambda_0>_y  count  \
# 0.0                                   1.223077  ...      0.029878  127.0
# 1.0                                   1.264146  ...      0.029878  127.0
# 2.0                                   1.181520  ...      0.029878  127.0
# 3.0                                   1.246377  ...      0.029878  127.0
# 4.0                                   1.251969  ...      0.029878  127.0
# ...                                        ...  ...           ...    ...
# 7571823.0                             1.192308  ...      0.012615  159.0
# 7571824.0                             1.191077  ...      0.012615  159.0
# 7571825.0                             1.178295  ...      0.012615  159.0
# 7571826.0                             1.214000  ...      0.012615  159.0
# 7571827.0                             1.175344  ...      0.012615  159.0
#
#            Abundance  z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 0.0         4.867534    -0.799651      -0.620910                 0.125106
# 1.0         4.812184    -0.193858      -1.030582                 0.125106
# 2.0         4.828314     0.349437      -0.911201                 0.125106
# 3.0         4.927254    -0.661603      -0.178900                 0.125106
# 4.0         4.844187    -0.514413      -0.793715                 0.125106
# ...              ...          ...            ...                      ...
# 7571823.0   4.867534    -0.089417       0.014743                 0.052237
# 7571824.0   4.867534    -0.528462       0.014743                 0.052237
# 7571825.0   4.859812     0.051342      -0.224311                 0.052237
# 7571826.0   4.867534    -0.421331       0.014743                 0.052237
# 7571827.0   4.875197    -0.351662       0.251966                 0.052237
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 0.0                     0.161081            None                None
# 1.0                     0.161081            None                None
# 2.0                     0.161081            None                None
# 3.0                     0.161081            None                None
# 4.0                     0.161081            None                None
# ...                          ...             ...                 ...
# 7571823.0               0.513151            None                None
# 7571824.0               0.513151            None                None
# 7571825.0               0.513151            None                None
# 7571826.0               0.513151            None                None
# 7571827.0               0.513151            None                None
#
#                        Strain_frame
# 0.0         d0222r2p740200f0001YOF1
# 1.0         d0222r2p740200f0001YOF1
# 2.0         d0222r2p740200f0001YOF1
# 3.0         d0222r2p740200f0001YOF1
# 4.0         d0222r2p740200f0001YOF1
# ...                             ...
# 7571823.0  d0214r2p090200f0048PPH22
# 7571824.0  d0214r2p090200f0048PPH22
# 7571825.0  d0214r2p090200f0048PPH22
# 7571826.0  d0214r2p090200f0048PPH22
# 7571827.0  d0214r2p090200f0048PPH22
#
# [7571828 rows x 91 columns]

# %%
Population_abundnace = Localization_information.groupby('Strain_frame').Abundance.agg('mean')

# %%
Population_abundnace
# Out:
# Strain_frame
# d0213r1p020100f0001YLR297W     4.835372
# d0213r1p020100f0002YLR297W     4.839550
# d0213r1p020100f0003YLR297W     4.832619
# d0213r1p020100f0004YLR297W     4.834376
# d0213r1p020100f0005YLR297W     4.833562
#                                  ...
# d0224r1p1090200f0062Contam.    4.890521
# d0224r1p1090200f0063Contam.    4.891173
# d0224r1p1090200f0064Contam.    4.892819
# d0224r1p1090200f0065Contam.    4.893172
# d0224r1p1090200f0066Contam.    4.894118
# Name: Abundance, Length: 32044, dtype: float64

# %%
Localization_information.columns
# Out:
# Index(['Unnamed: 0', 'Protein', 'Frame_x', 'Cell_Barcode', 'ImageID', 'Date',
#        'Unique_Frame', 'x90thPercentile_norm_OBJ_Median_GFP',
#        'x95thPercentile_norm_OBJ_Median_GFP',
#        'x99thPercentile_norm_OBJ_Median_GFP', 'Progen_bud',
#        'x80thPercentile_Diff_background_mKate',
#        'x90thPercentile_Diff_background_mKate',
#        'x99thPercentile_Diff_background_mKate',
#        'x80thPercentile_Diff_background_mKO',
#        'x90thPercentile_Diff_background_mKO',
#        'x99thPercentile_Diff_background_mKO', 'averageIntensity_mKO_Frame',
#        'averageIntesntiy_mKO_Background', 'averageIntensity_mKO_Object',
#        'mKO_spread', 'averageIntensity_mKate_Frame',
#        'averageIntesntiy_mKate_Background', 'averageIntensity_mKate_Object',
#        'mKate_spread', 'factor_median_OBJ_GFP', 'factor_mean_OBJ_GFP',
#        'factor_median _OBJ_KO', 'factor_mean_OBJ_KO', 'factor_total_OBJ_KO',
#        'factor_mKO_background_Med', 'factor_mKO_background_Avg',
#        'factor_mKO_background_Tot', 'factor_median_OBJ_mKate',
#        'factor_mean_OBJ_mKate', 'factor_total_OBJ_mKate',
#        'factor_mKate_background_Med', 'factor_mKate_background_Avg',
#        'factor_mKate_background_Tot', 'x90thPercentile_GFP_RAW',
#        'x95thPercentile_GFP_RAW', 'x99thPercentile_GFP_RAW', 'max_GFP_RAW',
#        'x60thPercentile_mKa_RAW', 'x80thPercentile_mKa_RAW',
#        'x90thPercentile_mKa_RAW', 'x95thPercentile_mKa_RAW',
#        'x99thPercentile_mKa_RAW', 'max_mKa_RAW', 'x60thPercentile_mKO_RAW',
#        'x80thPercentile_mKO_RAW', 'x90thPercentile_mKO_RAW',
#        'x95thPercentile_mKO_RAW', 'x99thPercentile_mKO_RAW', 'max_mKO_RAW',
#        'TrackID_valid', 'Myo1Identity', 'mKO_foldChange', 'mKO_direction',
#        'mKA_foldChange', 'mKa_direction', 'byProgen_bud', 'byRange',
#        'Col_info', 'Is_treated', 'Frames_post_treatment', 'Unique_pos',
#        'Loc_score', 'Upper', 'Lower', 'Relocalized', 'mKa_factor_upper',
#        'mKa_factor_lower', 'mKa_RAWfactor_upper', 'mKa_RAWfactor_lower',
#        '<lambda_0>_x', 'cell_count', 'mKO_factor_upper', 'mKO_factor_lower',
#        'mKO_RAWfactor_upper', 'mKO_RAWfactor_lower', '<lambda_0>_y', 'count',
#        'Abundance', 'z_score_Loc', 'z_score_Abund', 'Pearson_coeff_Loc_Abund',
#        'Signif_corr_Loc_Abund', 'Systematic ORF', 'Location_simplfied',
#        'Strain_frame'],
#       dtype='object')

# %%
Localization_information.groupby('Strain_frame')[["Frames_post_treatment", "Abundance"]].agg('mean')
# Out:
#                              Frames_post_treatment  Abundance
# Strain_frame
# d0213r1p020100f0001YLR297W                   -14.0   4.835372
# d0213r1p020100f0002YLR297W                   -13.0   4.839550
# d0213r1p020100f0003YLR297W                   -12.0   4.832619
# d0213r1p020100f0004YLR297W                   -11.0   4.834376
# d0213r1p020100f0005YLR297W                   -10.0   4.833562
# ...                                            ...        ...
# d0224r1p1090200f0062Contam.                   31.0   4.890521
# d0224r1p1090200f0063Contam.                   32.0   4.891173
# d0224r1p1090200f0064Contam.                   33.0   4.892819
# d0224r1p1090200f0065Contam.                   34.0   4.893172
# d0224r1p1090200f0066Contam.                   35.0   4.894118
#
# [32044 rows x 2 columns]

# %%
#Todo: complete functions
def relate_compare(cell_value, pop_value, mol_value):
	ratio = mol_value/pop_value
	#* There may need to be a log tranformation
	cell_mol = cell_value * ratio

def convert_time_frames(df, hrs, frame_gap = 7.5):
	frames_post = (hrs*60)/(frame_gap)
	return(df.loc['Frames_post_treatment'] == frames_post)

def convert_frames_time(x, frame_gap = 7.5)
	hours_post = (x*frame_gap)/60
# Out:
#   Cell In[18], line 12
#     def convert_frames_time(x, frame_gap = 7.5)
#                                                ^
# SyntaxError: invalid syntax

# %%
#Todo: complete functions
def relate_compare(cell_value, pop_value, mol_value):
	ratio = mol_value/pop_value
	#* There may need to be a log tranformation
	cell_mol = cell_value * ratio

def convert_time_frames(df, hrs, frame_gap = 7.5):
	frames_post = (hrs*60)/(frame_gap)
	return(df.loc['Frames_post_treatment'] == frames_post)

def convert_frames_time(x, frame_gap = 7.5):
	hours_post = (x*frame_gap)/60

# %%
#Todo: complete functions
def relate_compare(cell_value, pop_value, mol_value):
	ratio = mol_value/pop_value
	#* There may need to be a log tranformation
	cell_mol = cell_value * ratio

def convert_time_frames(df, hrs, frame_gap = 7.5):
	frames_post = (hrs*60)/(frame_gap)
	return(df.loc['Frames_post_treatment'] == frames_post)

def convert_frames_time(x, frame_gap = 7.5):
	time_post_post = (x*frame_gap) #. Decide if this should be in hours or minutes
	return(time_post_post)

# %%
# grouped = Localization_information.groupby('Strain_frame')
try: Localization_information['Time_post_treatment']:
except NameError:
	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
# Out:
#   Cell In[21], line 3
#     try: Localization_information['Time_post_treatment']:
#                                                          ^
# SyntaxError: invalid syntax

# %%
# grouped = Localization_information.groupby('Strain_frame')
try: Localization_information['Time_post_treatment']
except NameError:
	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time_post_treatment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pcnba\Grant Brown's Lab Dropbox\Peter Bartlett\Peter Bartlett Data\Code\single_cell_reloc\single_cell_reloc_parquet\Post_quant\Comparing_to_abundnace.py in line 3
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=58'>59</a> #%%
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=59'>60</a> # grouped = Localization_information.groupby('Strain_frame')
# ----> <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=60'>61</a> try: Localization_information['Time_post_treatment']
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=61'>62</a> except NameError:
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=62'>63</a> 	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'Time_post_treatment'

# %%
# grouped = Localization_information.groupby('Strain_frame')
try: Localization_information['Time_post_treatment']
except KeyErrorError:
	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time_post_treatment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pcnba\Grant Brown's Lab Dropbox\Peter Bartlett\Peter Bartlett Data\Code\single_cell_reloc\single_cell_reloc_parquet\Post_quant\Comparing_to_abundnace.py in line 3
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=58'>59</a> #%%
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=59'>60</a> # grouped = Localization_information.groupby('Strain_frame')
# ----> <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=60'>61</a> try: Localization_information['Time_post_treatment']
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=61'>62</a> except KeyErrorError:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#
# KeyError: 'Time_post_treatment'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# c:\Users\pcnba\Grant Brown's Lab Dropbox\Peter Bartlett\Peter Bartlett Data\Code\single_cell_reloc\single_cell_reloc_parquet\Post_quant\Comparing_to_abundnace.py in line 4
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=58'>59</a> #%%
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=59'>60</a> # grouped = Localization_information.groupby('Strain_frame')
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=60'>61</a> try: Localization_information['Time_post_treatment']
# ----> <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=61'>62</a> except KeyErrorError:
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=62'>63</a> 	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
#
# NameError: name 'KeyErrorError' is not defined

# %%
# grouped = Localization_information.groupby('Strain_frame')
try: Localization_information['Time_post_treatment']
except KeyError:
	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time_post_treatment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pcnba\Grant Brown's Lab Dropbox\Peter Bartlett\Peter Bartlett Data\Code\single_cell_reloc\single_cell_reloc_parquet\Post_quant\Comparing_to_abundnace.py in line 3
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=58'>59</a> #%%
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=59'>60</a> # grouped = Localization_information.groupby('Strain_frame')
# ----> <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=60'>61</a> try: Localization_information['Time_post_treatment']
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=61'>62</a> except KeyError:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#
# KeyError: 'Time_post_treatment'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time_post_treatment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\pcnba\Grant Brown's Lab Dropbox\Peter Bartlett\Peter Bartlett Data\Code\single_cell_reloc\single_cell_reloc_parquet\Post_quant\Comparing_to_abundnace.py in line 5
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=60'>61</a> try: Localization_information['Time_post_treatment']
#       <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=61'>62</a> except KeyError:
# ----> <a href='file:///c%3A/Users/pcnba/Grant%20Brown%27s%20Lab%20Dropbox/Peter%20Bartlett/Peter%20Bartlett%20Data/Code/single_cell_reloc/single_cell_reloc_parquet/Post_quant/Comparing_to_abundnace.py?line=62'>63</a> 	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Time_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3804'>3805</a> if self.columns.nlevels > 1:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3805'>3806</a>     return self._getitem_multilevel(key)
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3806'>3807</a> indexer = self.columns.get_loc(key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3807'>3808</a> if is_integer(indexer):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/frame.py?line=3808'>3809</a>     indexer = [indexer]
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: 'Time_post_treatment'

# %%
# grouped = Localization_information.groupby('Strain_frame')
try: Localization_information['Time_post_treatment']
except KeyError:
	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Frames_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  count  Abundance  \
# 0.0                                   1.223077  ...  127.0   4.867534
# 1.0                                   1.264146  ...  127.0   4.812184
# 2.0                                   1.181520  ...  127.0   4.828314
# 3.0                                   1.246377  ...  127.0   4.927254
# 4.0                                   1.251969  ...  127.0   4.844187
# ...                                        ...  ...    ...        ...
# 7571823.0                             1.192308  ...  159.0   4.867534
# 7571824.0                             1.191077  ...  159.0   4.867534
# 7571825.0                             1.178295  ...  159.0   4.859812
# 7571826.0                             1.214000  ...  159.0   4.867534
# 7571827.0                             1.175344  ...  159.0   4.875197
#
#            z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 0.0          -0.799651      -0.620910                 0.125106
# 1.0          -0.193858      -1.030582                 0.125106
# 2.0           0.349437      -0.911201                 0.125106
# 3.0          -0.661603      -0.178900                 0.125106
# 4.0          -0.514413      -0.793715                 0.125106
# ...                ...            ...                      ...
# 7571823.0    -0.089417       0.014743                 0.052237
# 7571824.0    -0.528462       0.014743                 0.052237
# 7571825.0     0.051342      -0.224311                 0.052237
# 7571826.0    -0.421331       0.014743                 0.052237
# 7571827.0    -0.351662       0.251966                 0.052237
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 0.0                     0.161081            None                None
# 1.0                     0.161081            None                None
# 2.0                     0.161081            None                None
# 3.0                     0.161081            None                None
# 4.0                     0.161081            None                None
# ...                          ...             ...                 ...
# 7571823.0               0.513151            None                None
# 7571824.0               0.513151            None                None
# 7571825.0               0.513151            None                None
# 7571826.0               0.513151            None                None
# 7571827.0               0.513151            None                None
#
#                        Strain_frame  Time_post_treatment
# 0.0         d0222r2p740200f0001YOF1               -195.0
# 1.0         d0222r2p740200f0001YOF1               -195.0
# 2.0         d0222r2p740200f0001YOF1               -195.0
# 3.0         d0222r2p740200f0001YOF1               -195.0
# 4.0         d0222r2p740200f0001YOF1               -195.0
# ...                             ...                  ...
# 7571823.0  d0214r2p090200f0048PPH22                172.5
# 7571824.0  d0214r2p090200f0048PPH22                172.5
# 7571825.0  d0214r2p090200f0048PPH22                172.5
# 7571826.0  d0214r2p090200f0048PPH22                172.5
# 7571827.0  d0214r2p090200f0048PPH22                172.5
#
# [7571828 rows x 92 columns]

# %%
grouped = Localization_information.groupby('Strain_frame')
Population_abundnace = grouped[["Time_post_treatment", "Abundance"]].agg('mean')
zero_hrs_mean = Population_abundnace.loc[Population_abundnace['Time_post_treatment'] == 0]
two_hrs_mean = Population_abundnace.loc[Population_abundnace['Time_post_treatment'] == 120]
four_hrs_mean = Population_abundnace.loc[Population_abundnace['Time_post_treatment'] == 240]

# %%
four_hrs_mean
# Out:
#                              Time_post_treatment  Abundance
# Strain_frame
# d0213r1p020100f0047YLR297W                 240.0   4.837924
# d0213r1p020200f0047YLR297W                 240.0   4.847795
# d0213r1p020300f0047YLR297W                 240.0   4.882269
# d0213r1p030100f0047YLR297W                 240.0   4.840394
# d0213r1p030200f0047YLR297W                 240.0   4.844722
# ...                                          ...        ...
# d0223r1p940200f0059PRE3                    240.0   4.871836
# d0223r1p970300f0059PRE3                    240.0   4.899927
# d0224r1p1050200f0063Contam.                240.0   4.858755
# d0224r1p1060300f0063Contam.                240.0   4.918640
# d0224r1p1090200f0063Contam.                240.0   4.891173
#
# [377 rows x 2 columns]

# %%
zero_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 0].groupby('Strain_frame')['Abundance'].agg('mean')
two_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 120].groupby('Strain_frame')['Abundance'].agg('mean')
four_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 240].groupby('Strain_frame')['Abundance'].agg('mean')

# %%
zero_hrs_mean
# Out:
# Strain_frame
# d0213r1p020100f0015YLR297W     4.822956
# d0213r1p020200f0015YLR297W     4.834588
# d0213r1p020300f0015YLR297W     4.851860
# d0213r1p030100f0015YLR297W     4.832300
# d0213r1p030200f0015YLR297W     4.833558
#                                  ...
# d0223r1p940200f0027PRE3        4.868215
# d0223r1p970300f0027PRE3        4.891928
# d0224r1p1050200f0031Contam.    4.826897
# d0224r1p1060300f0031Contam.    4.863500
# d0224r1p1090200f0031Contam.    4.886641
# Name: Abundance, Length: 450, dtype: float64

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  count  Abundance  \
# 0.0                                   1.223077  ...  127.0   4.867534
# 1.0                                   1.264146  ...  127.0   4.812184
# 2.0                                   1.181520  ...  127.0   4.828314
# 3.0                                   1.246377  ...  127.0   4.927254
# 4.0                                   1.251969  ...  127.0   4.844187
# ...                                        ...  ...    ...        ...
# 7571823.0                             1.192308  ...  159.0   4.867534
# 7571824.0                             1.191077  ...  159.0   4.867534
# 7571825.0                             1.178295  ...  159.0   4.859812
# 7571826.0                             1.214000  ...  159.0   4.867534
# 7571827.0                             1.175344  ...  159.0   4.875197
#
#            z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 0.0          -0.799651      -0.620910                 0.125106
# 1.0          -0.193858      -1.030582                 0.125106
# 2.0           0.349437      -0.911201                 0.125106
# 3.0          -0.661603      -0.178900                 0.125106
# 4.0          -0.514413      -0.793715                 0.125106
# ...                ...            ...                      ...
# 7571823.0    -0.089417       0.014743                 0.052237
# 7571824.0    -0.528462       0.014743                 0.052237
# 7571825.0     0.051342      -0.224311                 0.052237
# 7571826.0    -0.421331       0.014743                 0.052237
# 7571827.0    -0.351662       0.251966                 0.052237
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 0.0                     0.161081            None                None
# 1.0                     0.161081            None                None
# 2.0                     0.161081            None                None
# 3.0                     0.161081            None                None
# 4.0                     0.161081            None                None
# ...                          ...             ...                 ...
# 7571823.0               0.513151            None                None
# 7571824.0               0.513151            None                None
# 7571825.0               0.513151            None                None
# 7571826.0               0.513151            None                None
# 7571827.0               0.513151            None                None
#
#                        Strain_frame  Time_post_treatment
# 0.0         d0222r2p740200f0001YOF1               -195.0
# 1.0         d0222r2p740200f0001YOF1               -195.0
# 2.0         d0222r2p740200f0001YOF1               -195.0
# 3.0         d0222r2p740200f0001YOF1               -195.0
# 4.0         d0222r2p740200f0001YOF1               -195.0
# ...                             ...                  ...
# 7571823.0  d0214r2p090200f0048PPH22                172.5
# 7571824.0  d0214r2p090200f0048PPH22                172.5
# 7571825.0  d0214r2p090200f0048PPH22                172.5
# 7571826.0  d0214r2p090200f0048PPH22                172.5
# 7571827.0  d0214r2p090200f0048PPH22                172.5
#
# [7571828 rows x 92 columns]

# %%
zero_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 0]

# %%
zero_hrs_mean
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 3556.0         3556.0    YOF1     27.0  d0222r2p740200c0013
# 3557.0         3557.0    YOF1     27.0  d0222r2p740200c0025
# 3558.0         3558.0    YOF1     27.0  d0222r2p740200c0030
# 3559.0         3559.0    YOF1     27.0  d0222r2p740200c0035
# 3560.0         3560.0    YOF1     27.0  d0222r2p740200c0042
# ...               ...     ...      ...                  ...
# 7565809.0      7826.0   PPH22     25.0  d0214r2p120200c0225
# 7565810.0      7827.0   PPH22     25.0  d0214r2p120200c0227
# 7565811.0      7828.0   PPH22     25.0  d0214r2p120200c0228
# 7565812.0      7829.0   PPH22     25.0  d0214r2p120200c0230
# 7565813.0      7830.0   PPH22     25.0  d0214r2p120200c0231
#
#                        ImageID   Date         Unique_Frame  \
# 3556.0     d0222r2p740200f0027  d0222  d0222r2p740200f0027
# 3557.0     d0222r2p740200f0027  d0222  d0222r2p740200f0027
# 3558.0     d0222r2p740200f0027  d0222  d0222r2p740200f0027
# 3559.0     d0222r2p740200f0027  d0222  d0222r2p740200f0027
# 3560.0     d0222r2p740200f0027  d0222  d0222r2p740200f0027
# ...                        ...    ...                  ...
# 7565809.0  d0214r2p120200f0025  d0214  d0214r2p120200f0025
# 7565810.0  d0214r2p120200f0025  d0214  d0214r2p120200f0025
# 7565811.0  d0214r2p120200f0025  d0214  d0214r2p120200f0025
# 7565812.0  d0214r2p120200f0025  d0214  d0214r2p120200f0025
# 7565813.0  d0214r2p120200f0025  d0214  d0214r2p120200f0025
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 3556.0                                1.119048
# 3557.0                                1.136213
# 3558.0                                1.139286
# 3559.0                                1.087649
# 3560.0                                1.096825
# ...                                        ...
# 7565809.0                             1.092063
# 7565810.0                             1.103175
# 7565811.0                             1.091200
# 7565812.0                             1.088710
# 7565813.0                             1.087137
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 3556.0                                1.150794
# 3557.0                                1.176080
# 3558.0                                1.208929
# 3559.0                                1.115538
# 3560.0                                1.131746
# ...                                        ...
# 7565809.0                             1.119048
# 7565810.0                             1.120238
# 7565811.0                             1.123200
# 7565812.0                             1.112903
# 7565813.0                             1.119502
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  count  Abundance  \
# 3556.0                                1.245952  ...  155.0   4.836282
# 3557.0                                1.259601  ...  155.0   5.013963
# 3558.0                                1.279762  ...  155.0   5.123964
# 3559.0                                1.172112  ...  155.0   4.832306
# 3560.0                                1.157460  ...  155.0   4.836282
# ...                                        ...  ...    ...        ...
# 7565809.0                             1.149683  ...  420.0   4.836282
# 7565810.0                             1.181190  ...  420.0   4.836282
# 7565811.0                             1.187200  ...  420.0   4.828314
# 7565812.0                             1.154839  ...  420.0   4.820282
# 7565813.0                             1.183320  ...  420.0   4.791650
#
#            z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 3556.0       -0.635829      -0.652540                -0.249537
# 3557.0       -0.135488       1.052604                -0.249537
# 3558.0        0.603555       2.108244                -0.249537
# 3559.0        1.165776      -0.690698                -0.249537
# 3560.0        1.766726      -0.652540                -0.249537
# ...                ...            ...                      ...
# 7565809.0     0.016706      -0.329149                 0.083073
# 7565810.0    -0.024333      -0.329149                 0.083073
# 7565811.0    -0.126060      -0.538693                 0.083073
# 7565812.0     0.229914      -0.749920                 0.083073
# 7565813.0     0.001029      -1.502868                 0.083073
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 3556.0                  0.001741            None                None
# 3557.0                  0.001741            None                None
# 3558.0                  0.001741            None                None
# 3559.0                  0.001741            None                None
# 3560.0                  0.001741            None                None
# ...                          ...             ...                 ...
# 7565809.0               0.089063            None                None
# 7565810.0               0.089063            None                None
# 7565811.0               0.089063            None                None
# 7565812.0               0.089063            None                None
# 7565813.0               0.089063            None                None
#
#                        Strain_frame  Time_post_treatment
# 3556.0      d0222r2p740200f0027YOF1                  0.0
# 3557.0      d0222r2p740200f0027YOF1                  0.0
# 3558.0      d0222r2p740200f0027YOF1                  0.0
# 3559.0      d0222r2p740200f0027YOF1                  0.0
# 3560.0      d0222r2p740200f0027YOF1                  0.0
# ...                             ...                  ...
# 7565809.0  d0214r2p120200f0025PPH22                  0.0
# 7565810.0  d0214r2p120200f0025PPH22                  0.0
# 7565811.0  d0214r2p120200f0025PPH22                  0.0
# 7565812.0  d0214r2p120200f0025PPH22                  0.0
# 7565813.0  d0214r2p120200f0025PPH22                  0.0
#
# [88474 rows x 92 columns]

# %%
zero_hrs_mean.groupby('Strain_frame')['Abundance'].agg('mean')
# Out:
# Strain_frame
# d0213r1p020100f0015YLR297W     4.822956
# d0213r1p020200f0015YLR297W     4.834588
# d0213r1p020300f0015YLR297W     4.851860
# d0213r1p030100f0015YLR297W     4.832300
# d0213r1p030200f0015YLR297W     4.833558
#                                  ...
# d0223r1p940200f0027PRE3        4.868215
# d0223r1p970300f0027PRE3        4.891928
# d0224r1p1050200f0031Contam.    4.826897
# d0224r1p1060300f0031Contam.    4.863500
# d0224r1p1090200f0031Contam.    4.886641
# Name: Abundance, Length: 450, dtype: float64

# %%
zero_hrs_mean.groupby('Strain_frame')['Abundance'].transform('mean')
# Out:
# 3556.0       4.912211
# 3557.0       4.912211
# 3558.0       4.912211
# 3559.0       4.912211
# 3560.0       4.912211
#                ...
# 7565809.0    4.849027
# 7565810.0    4.849027
# 7565811.0    4.849027
# 7565812.0    4.849027
# 7565813.0    4.849027
# Name: Abundance, Length: 88474, dtype: float64

# %%
zero_hrs_mean.groupby('Strain_frame')['Abundance'].aggregate('mean')
# Out:
# Strain_frame
# d0213r1p020100f0015YLR297W     4.822956
# d0213r1p020200f0015YLR297W     4.834588
# d0213r1p020300f0015YLR297W     4.851860
# d0213r1p030100f0015YLR297W     4.832300
# d0213r1p030200f0015YLR297W     4.833558
#                                  ...
# d0223r1p940200f0027PRE3        4.868215
# d0223r1p970300f0027PRE3        4.891928
# d0224r1p1050200f0031Contam.    4.826897
# d0224r1p1060300f0031Contam.    4.863500
# d0224r1p1090200f0031Contam.    4.886641
# Name: Abundance, Length: 450, dtype: float64

# %%
zero_hrs_mean['Strain_frame'].unique()
# Out:
# array(['d0222r2p740200f0027YOF1', 'd0222r2p770300f0027YOF1',
#        'd0222r2p800200f0027YOF1', 'd0223r1p240200f0027GYL1',
#        'd0223r1p270300f0027GYL1', 'd0223r1p300200f0027GYL1',
#        'd0224r1p1050200f0031Contam.', 'd0224r1p1060300f0031Contam.',
#        'd0224r1p1090200f0031Contam.', 'd0222r2p840200f0027BUD4',
#        'd0222r2p870300f0027BUD4', 'd0222r2p900200f0027BUD4',
#        'd0223r1p740200f0027RAD54', 'd0223r1p770300f0027RAD54',
#        'd0223r1p800200f0027RAD54', 'd0223r1p1040200f0027DIP5',
#        'd0223r1p1070300f0027DIP5', 'd0223r1p1100200f0027DIP5',
#        'd0222r2p1140200f0027DDC2d0222r2',
#        'd0222r2p1170300f0027DDC2d0222r2',
#        'd0222r2p1200200f0027DDC2d0222r2', 'd0222r2p240200f0027RAS1',
#        'd0222r2p270300f0027RAS1', 'd0222r2p300200f0027RAS1',
#        'd0223r1p640200f0027MRC1', 'd0223r1p670300f0027MRC1',
#        'd0223r1p700200f0027MRC1', 'd0222r1p1140200f0027DDC2d0222r1',
#        'd0222r1p1170300f0027DDC2d0222r1',
#        'd0222r1p1200200f0027DDC2d0222r1', 'd0223r1p440200f0027PEX21',
#        'd0223r1p470300f0027PEX21', 'd0223r1p500200f0027PEX21',
#        'd0223r1p340200f0027PRS5', 'd0223r1p370300f0027PRS5',
#        'd0223r1p400200f0027PRS5', 'd0221r1p940200f0027HSP26',
#        'd0221r1p970300f0027HSP26', 'd0221r1p1000200f0027HSP26',
#        'd0223r1p1140200f0027DDC2d0223r1',
#        'd0223r1p1170300f0027DDC2d0223r1',
#        'd0223r1p1200200f0027DDC2d0223r1', 'd0221r1p040200f0027ULP1',
#        'd0221r1p070300f0027ULP1', 'd0221r1p100200f0027ULP1',
#        'd0215r2p130300f0031DDC2d0215r2', 'd0215r2p130200f0031DDC2d0215r2',
#        'd0215r2p150200f0031DDC2d0215r2', 'd0215r2p150300f0031DDC2d0215r2',
#        'd0215r2p160200f0031DDC2d0215r2', 'd0215r2p160300f0031DDC2d0215r2',
#        'd0222r2p440200f0027DUS3', 'd0222r2p470300f0027DUS3',
#        'd0222r2p500200f0027DUS3', 'd0222r2p140200f0027YJR056C',
#        'd0222r2p170300f0027YJR056C', 'd0222r2p200200f0027YJR056C',
#        'd0222r2p340200f0027EXO1', 'd0222r2p370300f0027EXO1',
#        'd0222r2p400200f0027EXO1', 'd0222r1p540200f0027SVL3',
#        'd0222r1p570300f0027SVL3', 'd0222r1p600200f0027SVL3',
#        'd0222r1p340200f0027EDC2', 'd0222r1p370300f0027EDC2',
#        'd0222r1p400200f0027EDC2', 'd0222r1p440200f0027ATG3',
#        'd0222r1p470300f0027ATG3', 'd0222r1p500200f0027ATG3',
#        'd0221r1p840200f0027RMT2', 'd0221r1p870300f0027RMT2',
#        'd0221r1p900200f0027RMT2', 'd0222r1p840200f0027FGV2',
#        'd0222r1p870300f0027FGV2', 'd0222r1p900200f0027FGV2',
#        'd0222r1p740200f0027RME1', 'd0222r1p770300f0027RME1',
#        'd0222r1p800200f0027RME1', 'd0221r1p1040200f0027CYK3',
#        'd0221r1p1070300f0027CYK3', 'd0221r1p1100200f0027CYK3',
#        'd0221r1p640200f0027FAA4', 'd0221r1p670300f0027FAA4',
#        'd0221r1p700200f0027FAA4', 'd0221r1p340200f0027DSE3',
#        'd0221r1p370300f0027DSE3', 'd0221r1p400200f0027DSE3',
#        'd0222r1p240200f0027ECO1', 'd0222r1p270300f0027ECO1',
#        'd0222r1p300200f0027ECO1', 'd0222r1p170300f0027SIP5',
#        'd0222r1p200200f0027SIP5', 'd0221r1p740200f0027SLD3',
#        'd0221r1p770300f0027SLD3', 'd0221r1p800200f0027SLD3',
#        'd0220r2p1040200f0027NEJ1', 'd0220r2p1070300f0027NEJ1',
#        'd0220r2p1100200f0027NEJ1', 'd0220r2p1140200f0027DDC2d0220r2',
#        'd0220r2p1170300f0027DDC2d0220r2',
#        'd0220r2p1200200f0027DDC2d0220r2', 'd0221r1p540200f0027SQS1',
#        'd0221r1p570300f0027SQS1', 'd0221r1p600200f0027SQS1',
#        'd0220r2p640200f0027TRM112', 'd0220r2p670300f0027TRM112',
#        'd0220r2p700200f0027TRM112', 'd0221r1p240200f0027MGS1',
#        'd0221r1p270300f0027MGS1', 'd0221r1p300200f0027MGS1',
#        'd0220r2p140200f0027YDR115W', 'd0220r2p170300f0027YDR115W',
#        'd0220r2p200200f0027YDR115W', 'd0220r2p540200f0027RFC4',
#        'd0220r2p570300f0027RFC4', 'd0220r2p600200f0027RFC4',
#        'd0220r2p240200f0027SRS2', 'd0220r2p270300f0027SRS2',
#        'd0220r2p300200f0027SRS2', 'd0220r2p440200f0027YLR108C',
#        'd0220r2p470300f0027YLR108C', 'd0220r2p500200f0027YLR108C',
#        'd0220r1p1140200f0031DDC2d0220r1',
#        'd0220r1p1170300f0031DDC2d0220r1',
#        'd0220r1p1200200f0031DDC2d0220r1', 'd0220r2p040200f0027HSP42',
#        'd0220r2p070300f0027HSP42', 'd0220r2p100200f0027HSP42',
#        'd0220r1p240200f0031LSM4', 'd0220r1p270300f0031LSM4',
#        'd0220r1p300200f0031LSM4', 'd0215r1p050300f0030XRS2',
#        'd0215r1p050200f0030XRS2', 'd0215r1p070200f0030XRS2',
#        'd0215r1p070300f0030XRS2', 'd0215r1p080300f0030XRS2',
#        'd0215r1p080200f0030XRS2', 'd0220r1p1040200f0031TOP3',
#        'd0220r1p1070300f0031TOP3', 'd0220r1p1100200f0031TOP3',
#        'd0220r1p1000200f0031RGA1', 'd0219r1p1010200f0031DDC2d0219r1',
#        'd0219r1p1020200f0031DDC2d0219r1',
#        'd0219r1p1030200f0031DDC2d0219r1', 'd0219r1p640200f0031PPH21',
#        'd0219r1p670300f0031PPH21', 'd0219r1p700200f0031PPH21',
#        'd0218r1p840200f0023MTR10', 'd0218r1p870300f0023MTR10',
#        'd0218r1p900200f0023MTR10', 'd0219r1p740200f0031AIM20',
#        'd0219r1p770300f0031AIM20', 'd0219r1p800200f0031AIM20',
#        'd0219r1p540200f0031AFT1', 'd0219r1p570300f0031AFT1',
#        'd0219r1p600200f0031AFT1', 'd0219r1p340200f0031SNT2',
#        'd0219r1p370300f0031SNT2', 'd0219r1p400200f0031SNT2',
#        'd0218r2p1010200f0031YDR132C', 'd0218r2p1020200f0031YDR132C',
#        'd0218r2p1030200f0031YDR132C', 'd0219r1p180200f0031GIC1',
#        'd0219r1p190200f0031GIC1', 'd0219r1p200200f0031GIC1',
#        'd0218r1p640200f0023YGR042W', 'd0218r1p670300f0023YGR042W',
#        'd0218r1p700200f0023YGR042W', 'd0218r2p240200f0031CAP1',
#        'd0218r2p270300f0031CAP1', 'd0218r2p300200f0031CAP1',
#        'd0218r2p640200f0031NAM7', 'd0218r2p670300f0031NAM7',
#        'd0218r2p700200f0031NAM7', 'd0218r2p440200f0031HMG1',
#        'd0218r2p470300f0031HMG1', 'd0218r2p500200f0031HMG1',
#        'd0218r1p1010200f0023DDC2d0218r1',
#        'd0218r1p1020200f0023DDC2d0218r1',
#        'd0218r1p1030200f0023DDC2d0218r1', 'd0218r1p940200f0023TOF2',
#        'd0218r1p970300f0023TOF2', 'd0218r1p1000200f0023TOF2',
#        'd0218r2p180200f0031RNR4', 'd0218r2p190200f0031RNR4',
#        'd0218r2p200200f0031RNR4', 'd0215r2p050200f0031LSM2',
#        'd0215r2p050300f0031LSM2', 'd0215r2p070200f0031LSM2',
#        'd0215r2p070300f0031LSM2', 'd0215r2p080200f0031LSM2',
#        'd0215r2p080300f0031LSM2', 'd0218r1p740200f0023MRS8',
#        'd0218r1p770300f0023MRS8', 'd0218r1p800200f0023MRS8',
#        'd0217r2p840200f0031GTB1', 'd0217r2p870300f0031GTB1',
#        'd0217r2p900200f0031GTB1', 'd0217r2p640200f0031HAC1',
#        'd0217r2p670300f0031HAC1', 'd0217r2p700200f0031HAC1',
#        'd0218r1p440200f0023ACE2', 'd0218r1p470300f0023ACE2',
#        'd0218r1p500200f0023ACE2', 'd0217r2p440200f0031YKU70',
#        'd0217r2p470300f0031YKU70', 'd0217r2p500200f0031YKU70',
#        'd0217r2p1010200f0031DDC2d0217r2',
#        'd0217r2p1020300f0031DDC2d0217r2',
#        'd0217r2p1030200f0031DDC2d0217r2', 'd0218r1p540200f0023YDR348C',
#        'd0218r1p570300f0023YDR348C', 'd0218r1p600200f0023YDR348C',
#        'd0217r2p240200f0031YML011C', 'd0217r2p270300f0031YML011C',
#        'd0217r2p300200f0031YML011C', 'd0217r2p940200f0031APC5',
#        'd0217r2p970300f0031APC5', 'd0217r2p1000200f0031APC5',
#        'd0217r2p340200f0031CAF8', 'd0217r2p370300f0031CAF8',
#        'd0217r2p400200f0031CAF8', 'd0217r2p540200f0031CDC40',
#        'd0217r2p570300f0031CDC40', 'd0217r2p600200f0031CDC40',
#        'd0215r1p010200f0030CCC1', 'd0215r1p010300f0030CCC1',
#        'd0215r1p030200f0030CCC1', 'd0215r1p030300f0030CCC1',
#        'd0215r1p040200f0030CCC1', 'd0215r1p040300f0030CCC1',
#        'd0213r1p020100f0015YLR297W', 'd0213r1p020200f0015YLR297W',
#        'd0213r1p020300f0015YLR297W', 'd0213r1p030200f0015YLR297W',
#        'd0213r1p030100f0015YLR297W', 'd0213r1p030300f0015YLR297W',
#        'd0217r1p840200f0031GYP5', 'd0217r1p870300f0031GYP5',
#        'd0217r1p900200f0031GYP5', 'd0213r1p140200f0015DDC2d013r1',
#        'd0213r1p140100f0015DDC2d013r1', 'd0213r1p140300f0015DDC2d013r1',
#        'd0213r1p150300f0015DDC2d013r1', 'd0213r1p150100f0015DDC2d013r1',
#        'd0213r1p150200f0015DDC2d013r1', 'd0216r2p150200f0031DDC2d0216r2',
#        'd0216r2p160200f0031DDC2d0216r2', 'd0216r2p160300f0031DDC2d0216r2',
#        'd0216r1p130300f0031DDC2d0216r1', 'd0216r1p130200f0031DDC2d0216r1',
#        'd0216r1p150200f0031DDC2d0216r1', 'd0216r1p150300f0031DDC2d0216r1',
#        'd0216r1p160300f0031DDC2d0216r1', 'd0216r1p160200f0031DDC2d0216r1',
#        'd0217r1p740200f0031ULS1', 'd0217r1p770300f0031ULS1',
#        'd0217r1p800200f0031ULS1', 'd0215r1p130200f0030DDC2d0215r1',
#        'd0215r1p130300f0030DDC2d0215r1', 'd0215r1p150200f0030DDC2d0215r1',
#        'd0215r1p150300f0030DDC2d0215r1', 'd0215r1p160300f0030DDC2d0215r1',
#        'd0215r1p160200f0030DDC2d0215r1', 'd0214r2p050200f0025CHK1',
#        'd0214r2p050300f0025CHK1', 'd0214r2p070200f0025CHK1',
#        'd0214r2p070300f0025CHK1', 'd0214r2p080200f0025CHK1',
#        'd0214r2p080300f0025CHK1', 'd0217r1p540200f0031SUT1',
#        'd0217r1p570300f0031SUT1', 'd0217r1p600200f0031SUT1',
#        'd0216r2p080200f0031CTR86', 'd0217r1p140200f0031LSM3',
#        'd0217r1p170300f0031LSM3', 'd0217r1p200200f0031LSM3',
#        'd0216r1p050200f0031HOS2', 'd0216r1p010300f0031YKU80',
#        'd0216r1p010200f0031YKU80', 'd0216r1p030200f0031YKU80',
#        'd0216r1p030300f0031YKU80', 'd0216r1p040200f0031YKU80',
#        'd0216r1p090300f0031ATG29', 'd0216r1p110200f0031ATG29',
#        'd0216r1p120300f0031ATG29', 'd0213r1p060300f0015MSH3',
#        'd0213r1p060100f0015MSH3', 'd0213r1p060200f0015MSH3',
#        'd0213r1p070200f0015MSH3', 'd0213r1p070300f0015MSH3',
#        'd0213r1p070100f0015MSH3', 'd0214r2p130200f0025DDC2d0214r2',
#        'd0214r2p130300f0025DDC2d0214r2', 'd0214r2p150300f0025DDC2d0214r2',
#        'd0214r2p160200f0025DDC2d0214r2', 'd0214r2p160300f0025DDC2d0214r2',
#        'd0214r2p010300f0025GSY1', 'd0214r2p030300f0025GSY1',
#        'd0214r2p030200f0025GSY1', 'd0214r2p040300f0025GSY1',
#        'd0214r2p040200f0025GSY1', 'd0223r1p940200f0027PRE3',
#        'd0223r1p970300f0027PRE3', 'd0223r1p1000200f0027PRE3',
#        'd0223r1p140200f0027RRP5', 'd0223r1p170300f0027RRP5',
#        'd0223r1p200200f0027RRP5', 'd0223r1p040200f0027SEC11',
#        'd0223r1p070300f0027SEC11', 'd0223r1p100200f0027SEC11',
#        'd0221r1p1140200f0027DDC2d0221r1',
#        'd0221r1p1170300f0027DDC2d0221r1',
#        'd0221r1p1200200f0027DDC2d0221r1', 'd0223r1p540200f0027AGR2',
#        'd0223r1p570300f0027AGR2', 'd0223r1p600200f0027AGR2',
#        'd0223r1p840200f0027CDC14', 'd0223r1p870300f0027CDC14',
#        'd0223r1p900200f0027CDC14', 'd0222r2p040200f0027HGH1',
#        'd0222r2p070300f0027HGH1', 'd0222r2p100200f0027HGH1',
#        'd0222r2p1040200f0027SAE2', 'd0222r2p1070300f0027SAE2',
#        'd0222r2p1100200f0027SAE2', 'd0222r2p540200f0027MOB1',
#        'd0222r2p570300f0027MOB1', 'd0222r2p600200f0027MOB1',
#        'd0222r1p940200f0027ESP2', 'd0222r1p970300f0027ESP2',
#        'd0222r1p1000200f0027ESP2', 'd0222r2p940200f0027CDC20',
#        'd0222r2p970300f0027CDC20', 'd0222r2p1000200f0027CDC20',
#        'd0222r1p1040200f0027TDR3', 'd0222r1p1070300f0027TDR3',
#        'd0222r1p1100200f0027TDR3', 'd0222r2p640200f0027YBR197C',
#        'd0222r2p670300f0027YBR197C', 'd0222r2p700200f0027YBR197C',
#        'd0222r1p640200f0027ARP4', 'd0222r1p670300f0027ARP4',
#        'd0222r1p700200f0027ARP4', 'd0221r1p440200f0027EDC1',
#        'd0221r1p470300f0027EDC1', 'd0221r1p140200f0027CDC24',
#        'd0221r1p170300f0027CDC24', 'd0221r1p200200f0027CDC24',
#        'd0222r1p070300f0027GCD8', 'd0220r2p740200f0027UFD4',
#        'd0220r2p770300f0027UFD4', 'd0220r2p800200f0027UFD4',
#        'd0220r2p340200f0027YMR160W', 'd0220r2p370300f0027YMR160W',
#        'd0220r2p400200f0027YMR160W', 'd0215r2p090200f0031YAR009C',
#        'd0215r2p090300f0031YAR009C', 'd0215r2p110300f0031YAR009C',
#        'd0215r2p110200f0031YAR009C', 'd0215r2p120300f0031YAR009C',
#        'd0215r2p120200f0031YAR009C', 'd0220r2p840200f0027CDC27',
#        'd0220r2p870300f0027CDC27', 'd0220r2p900200f0027CDC27',
#        'd0220r2p940200f0027TUB1', 'd0220r2p970300f0027TUB1',
#        'd0220r2p1000200f0027TUB1', 'd0220r1p140200f0031ARO4',
#        'd0220r1p170300f0031ARO4', 'd0220r1p200200f0031ARO4',
#        'd0218r2p840200f0031FAR1', 'd0218r2p870300f0031FAR1',
#        'd0218r2p900200f0031FAR1', 'd0220r1p440200f0031RAD9',
#        'd0220r1p470300f0031RAD9', 'd0220r1p340200f0031YML108W',
#        'd0220r1p370300f0031YML108W', 'd0220r1p400200f0031YML108W',
#        'd0219r1p940200f0031REV1', 'd0219r1p970300f0031REV1',
#        'd0219r1p1000200f0031REV1', 'd0219r1p840200f0031RAD55',
#        'd0219r1p870300f0031RAD55', 'd0219r1p900200f0031RAD55',
#        'd0219r1p440200f0031DBF4', 'd0219r1p470300f0031DBF4',
#        'd0219r1p500200f0031DBF4', 'd0218r2p940200f0031DDC1',
#        'd0218r2p970300f0031DDC1', 'd0218r2p1000200f0031DDC1',
#        'd0219r1p240200f0031IWR1', 'd0219r1p270300f0031IWR1',
#        'd0219r1p300200f0031IWR1', 'd0218r2p340200f0031NMD4',
#        'd0218r2p370300f0031NMD4', 'd0218r2p400200f0031NMD4',
#        'd0218r2p540200f0031TSC13', 'd0218r2p570300f0031TSC13',
#        'd0218r2p600200f0031TSC13', 'd0218r1p240200f0023ITR1',
#        'd0218r1p270300f0023ITR1', 'd0218r1p300200f0023ITR1',
#        'd0217r2p740200f0031AAC1', 'd0217r2p770300f0031AAC1',
#        'd0217r2p800200f0031AAC1', 'd0218r1p340200f0023APC1',
#        'd0218r1p370300f0023APC1', 'd0218r1p400200f0023APC1',
#        'd0217r1p1010200f0031DDC2d0217r1',
#        'd0217r1p1020300f0031DDC2d0217r1',
#        'd0217r1p1030200f0031DDC2d0217r1', 'd0218r1p180200f0023YLR126C',
#        'd0218r1p190200f0023YLR126C', 'd0218r1p200200f0023YLR126C',
#        'd0217r1p940200f0031STB4', 'd0217r1p970300f0031STB4',
#        'd0217r1p1000200f0031STB4', 'd0217r1p240200f0031CBP2',
#        'd0217r1p270300f0031CBP2', 'd0217r1p300200f0031CBP2',
#        'd0217r2p140200f0031HNT3', 'd0217r2p170300f0031HNT3',
#        'd0217r2p200200f0031HNT3', 'd0217r1p440200f0031TOS4',
#        'd0217r1p470300f0031TOS4', 'd0217r1p500200f0031TOS4',
#        'd0217r1p640200f0031LSM7', 'd0217r1p670300f0031LSM7',
#        'd0217r1p700200f0031LSM7', 'd0217r1p340200f0031SCH9',
#        'd0217r1p370300f0031SCH9', 'd0217r1p400200f0031SCH9',
#        'd0215r2p010200f0031AME1', 'd0215r2p010300f0031AME1',
#        'd0215r2p030200f0031AME1', 'd0215r2p030300f0031AME1',
#        'd0215r2p040300f0031AME1', 'd0215r2p040200f0031AME1',
#        'd0215r1p090300f0030PSO2', 'd0215r1p090200f0030PSO2',
#        'd0215r1p110200f0030PSO2', 'd0215r1p110300f0030PSO2',
#        'd0215r1p120200f0030PSO2', 'd0215r1p120300f0030PSO2',
#        'd0214r2p090200f0025PPH22', 'd0214r2p110200f0025PPH22',
#        'd0214r2p110300f0025PPH22', 'd0214r2p120300f0025PPH22',
#        'd0214r2p120200f0025PPH22'], dtype=object)

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  count  Abundance  \
# 0.0                                   1.223077  ...  127.0   4.867534
# 1.0                                   1.264146  ...  127.0   4.812184
# 2.0                                   1.181520  ...  127.0   4.828314
# 3.0                                   1.246377  ...  127.0   4.927254
# 4.0                                   1.251969  ...  127.0   4.844187
# ...                                        ...  ...    ...        ...
# 7571823.0                             1.192308  ...  159.0   4.867534
# 7571824.0                             1.191077  ...  159.0   4.867534
# 7571825.0                             1.178295  ...  159.0   4.859812
# 7571826.0                             1.214000  ...  159.0   4.867534
# 7571827.0                             1.175344  ...  159.0   4.875197
#
#            z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 0.0          -0.799651      -0.620910                 0.125106
# 1.0          -0.193858      -1.030582                 0.125106
# 2.0           0.349437      -0.911201                 0.125106
# 3.0          -0.661603      -0.178900                 0.125106
# 4.0          -0.514413      -0.793715                 0.125106
# ...                ...            ...                      ...
# 7571823.0    -0.089417       0.014743                 0.052237
# 7571824.0    -0.528462       0.014743                 0.052237
# 7571825.0     0.051342      -0.224311                 0.052237
# 7571826.0    -0.421331       0.014743                 0.052237
# 7571827.0    -0.351662       0.251966                 0.052237
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 0.0                     0.161081            None                None
# 1.0                     0.161081            None                None
# 2.0                     0.161081            None                None
# 3.0                     0.161081            None                None
# 4.0                     0.161081            None                None
# ...                          ...             ...                 ...
# 7571823.0               0.513151            None                None
# 7571824.0               0.513151            None                None
# 7571825.0               0.513151            None                None
# 7571826.0               0.513151            None                None
# 7571827.0               0.513151            None                None
#
#                        Strain_frame  Time_post_treatment
# 0.0         d0222r2p740200f0001YOF1               -195.0
# 1.0         d0222r2p740200f0001YOF1               -195.0
# 2.0         d0222r2p740200f0001YOF1               -195.0
# 3.0         d0222r2p740200f0001YOF1               -195.0
# 4.0         d0222r2p740200f0001YOF1               -195.0
# ...                             ...                  ...
# 7571823.0  d0214r2p090200f0048PPH22                172.5
# 7571824.0  d0214r2p090200f0048PPH22                172.5
# 7571825.0  d0214r2p090200f0048PPH22                172.5
# 7571826.0  d0214r2p090200f0048PPH22                172.5
# 7571827.0  d0214r2p090200f0048PPH22                172.5
#
# [7571828 rows x 92 columns]

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  count  Abundance  \
# 0.0                                   1.223077  ...  127.0   4.867534
# 1.0                                   1.264146  ...  127.0   4.812184
# 2.0                                   1.181520  ...  127.0   4.828314
# 3.0                                   1.246377  ...  127.0   4.927254
# 4.0                                   1.251969  ...  127.0   4.844187
# ...                                        ...  ...    ...        ...
# 7571823.0                             1.192308  ...  159.0   4.867534
# 7571824.0                             1.191077  ...  159.0   4.867534
# 7571825.0                             1.178295  ...  159.0   4.859812
# 7571826.0                             1.214000  ...  159.0   4.867534
# 7571827.0                             1.175344  ...  159.0   4.875197
#
#            z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 0.0          -0.799651      -0.620910                 0.125106
# 1.0          -0.193858      -1.030582                 0.125106
# 2.0           0.349437      -0.911201                 0.125106
# 3.0          -0.661603      -0.178900                 0.125106
# 4.0          -0.514413      -0.793715                 0.125106
# ...                ...            ...                      ...
# 7571823.0    -0.089417       0.014743                 0.052237
# 7571824.0    -0.528462       0.014743                 0.052237
# 7571825.0     0.051342      -0.224311                 0.052237
# 7571826.0    -0.421331       0.014743                 0.052237
# 7571827.0    -0.351662       0.251966                 0.052237
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 0.0                     0.161081            None                None
# 1.0                     0.161081            None                None
# 2.0                     0.161081            None                None
# 3.0                     0.161081            None                None
# 4.0                     0.161081            None                None
# ...                          ...             ...                 ...
# 7571823.0               0.513151            None                None
# 7571824.0               0.513151            None                None
# 7571825.0               0.513151            None                None
# 7571826.0               0.513151            None                None
# 7571827.0               0.513151            None                None
#
#                        Strain_frame  Time_post_treatment
# 0.0         d0222r2p740200f0001YOF1               -195.0
# 1.0         d0222r2p740200f0001YOF1               -195.0
# 2.0         d0222r2p740200f0001YOF1               -195.0
# 3.0         d0222r2p740200f0001YOF1               -195.0
# 4.0         d0222r2p740200f0001YOF1               -195.0
# ...                             ...                  ...
# 7571823.0  d0214r2p090200f0048PPH22                172.5
# 7571824.0  d0214r2p090200f0048PPH22                172.5
# 7571825.0  d0214r2p090200f0048PPH22                172.5
# 7571826.0  d0214r2p090200f0048PPH22                172.5
# 7571827.0  d0214r2p090200f0048PPH22                172.5
#
# [7571828 rows x 92 columns]

# %%
Localization_information.columns
# Out:
# Index(['Unnamed: 0', 'Protein', 'Frame_x', 'Cell_Barcode', 'ImageID', 'Date',
#        'Unique_Frame', 'x90thPercentile_norm_OBJ_Median_GFP',
#        'x95thPercentile_norm_OBJ_Median_GFP',
#        'x99thPercentile_norm_OBJ_Median_GFP', 'Progen_bud',
#        'x80thPercentile_Diff_background_mKate',
#        'x90thPercentile_Diff_background_mKate',
#        'x99thPercentile_Diff_background_mKate',
#        'x80thPercentile_Diff_background_mKO',
#        'x90thPercentile_Diff_background_mKO',
#        'x99thPercentile_Diff_background_mKO', 'averageIntensity_mKO_Frame',
#        'averageIntesntiy_mKO_Background', 'averageIntensity_mKO_Object',
#        'mKO_spread', 'averageIntensity_mKate_Frame',
#        'averageIntesntiy_mKate_Background', 'averageIntensity_mKate_Object',
#        'mKate_spread', 'factor_median_OBJ_GFP', 'factor_mean_OBJ_GFP',
#        'factor_median _OBJ_KO', 'factor_mean_OBJ_KO', 'factor_total_OBJ_KO',
#        'factor_mKO_background_Med', 'factor_mKO_background_Avg',
#        'factor_mKO_background_Tot', 'factor_median_OBJ_mKate',
#        'factor_mean_OBJ_mKate', 'factor_total_OBJ_mKate',
#        'factor_mKate_background_Med', 'factor_mKate_background_Avg',
#        'factor_mKate_background_Tot', 'x90thPercentile_GFP_RAW',
#        'x95thPercentile_GFP_RAW', 'x99thPercentile_GFP_RAW', 'max_GFP_RAW',
#        'x60thPercentile_mKa_RAW', 'x80thPercentile_mKa_RAW',
#        'x90thPercentile_mKa_RAW', 'x95thPercentile_mKa_RAW',
#        'x99thPercentile_mKa_RAW', 'max_mKa_RAW', 'x60thPercentile_mKO_RAW',
#        'x80thPercentile_mKO_RAW', 'x90thPercentile_mKO_RAW',
#        'x95thPercentile_mKO_RAW', 'x99thPercentile_mKO_RAW', 'max_mKO_RAW',
#        'TrackID_valid', 'Myo1Identity', 'mKO_foldChange', 'mKO_direction',
#        'mKA_foldChange', 'mKa_direction', 'byProgen_bud', 'byRange',
#        'Col_info', 'Is_treated', 'Frames_post_treatment', 'Unique_pos',
#        'Loc_score', 'Upper', 'Lower', 'Relocalized', 'mKa_factor_upper',
#        'mKa_factor_lower', 'mKa_RAWfactor_upper', 'mKa_RAWfactor_lower',
#        '<lambda_0>_x', 'cell_count', 'mKO_factor_upper', 'mKO_factor_lower',
#        'mKO_RAWfactor_upper', 'mKO_RAWfactor_lower', '<lambda_0>_y', 'count',
#        'Abundance', 'z_score_Loc', 'z_score_Abund', 'Pearson_coeff_Loc_Abund',
#        'Signif_corr_Loc_Abund', 'Systematic ORF', 'Location_simplfied',
#        'Strain_frame', 'Time_post_treatment'],
#       dtype='object')

# %%
Localization_information['ImageID'][:-5] + Localization_information['Protein']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:1577, in pandas._libs.hashtable.Float64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:1587, in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: -5.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Localization_information['ImageID'][:-5] + Localization_information['Protein']
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1003'>1004</a>     key = np.asarray(key, dtype=bool)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1004'>1005</a>     return self._get_values(key)
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1006'>1007</a> return self._get_with(key)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\series.py:1014, in Series._get_with(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1008'>1009</a> def _get_with(self, key):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1009'>1010</a>     # other: fancy integer or otherwise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1010'>1011</a>     if isinstance(key, slice):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1011'>1012</a>         # _convert_slice_indexer to determine if this slice is positional
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1012'>1013</a>         #  or label based, and if the latter, convert to positional
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1013'>1014</a>         slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1014'>1015</a>         return self._slice(slobj)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1015'>1016</a>     elif isinstance(key, ABCDataFrame):
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\numeric.py:232, in NumericIndex._convert_slice_indexer(self, key, kind)
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=225'>226</a>     assert kind in ["loc", "getitem"]
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=227'>228</a>     # TODO: can we write this as a condition based on
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=228'>229</a>     #  e.g. _should_fallback_to_positional?
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=229'>230</a>     # We always treat __getitem__ slicing as label-based
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=230'>231</a>     # translate to locations
# --> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=231'>232</a>     return self.slice_indexer(key.start, key.stop, key.step)
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=233'>234</a> return super()._convert_slice_indexer(key, kind=kind)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6515'>6516</a> """
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6516'>6517</a> Compute the slice indexer for input labels and step.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6517'>6518</a>
#    (...)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6554'>6555</a> slice(1, 3, None)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6555'>6556</a> """
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6556'>6557</a> self._deprecated_arg(kind, "kind", "slice_indexer")
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6558'>6559</a> start_slice, end_slice = self.slice_locs(start, end, step=step)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6560'>6561</a> # return a slice
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6561'>6562</a> if not is_scalar(start_slice):
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6773, in Index.slice_locs(self, start, end, step, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6770'>6771</a> end_slice = None
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6771'>6772</a> if end is not None:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6772'>6773</a>     end_slice = self.get_slice_bound(end, "right")
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6773'>6774</a> if end_slice is None:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6774'>6775</a>     end_slice = len(self)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6686, in Index.get_slice_bound(self, label, side, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6682'>6683</a>         return self._searchsorted_monotonic(label, side)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6683'>6684</a>     except ValueError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6684'>6685</a>         # raise the original KeyError
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6685'>6686</a>         raise err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6687'>6688</a> if isinstance(slc, np.ndarray):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6688'>6689</a>     # get_loc may return a boolean array, which
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6689'>6690</a>     # is OK as long as they are representable by a slice.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6690'>6691</a>     assert is_bool_dtype(slc.dtype)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6680, in Index.get_slice_bound(self, label, side, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6677'>6678</a> # we need to look up the label
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6678'>6679</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6679'>6680</a>     slc = self.get_loc(label)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6680'>6681</a> except KeyError as err:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6681'>6682</a>     try:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: -5

# %%
Localization_information['ImageID'][:-5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:1577, in pandas._libs.hashtable.Float64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:1587, in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: -5.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 Localization_information['ImageID'][:-5]
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1003'>1004</a>     key = np.asarray(key, dtype=bool)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1004'>1005</a>     return self._get_values(key)
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1006'>1007</a> return self._get_with(key)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\series.py:1014, in Series._get_with(self, key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1008'>1009</a> def _get_with(self, key):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1009'>1010</a>     # other: fancy integer or otherwise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1010'>1011</a>     if isinstance(key, slice):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1011'>1012</a>         # _convert_slice_indexer to determine if this slice is positional
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1012'>1013</a>         #  or label based, and if the latter, convert to positional
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1013'>1014</a>         slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1014'>1015</a>         return self._slice(slobj)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/series.py?line=1015'>1016</a>     elif isinstance(key, ABCDataFrame):
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\numeric.py:232, in NumericIndex._convert_slice_indexer(self, key, kind)
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=225'>226</a>     assert kind in ["loc", "getitem"]
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=227'>228</a>     # TODO: can we write this as a condition based on
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=228'>229</a>     #  e.g. _should_fallback_to_positional?
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=229'>230</a>     # We always treat __getitem__ slicing as label-based
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=230'>231</a>     # translate to locations
# --> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=231'>232</a>     return self.slice_indexer(key.start, key.stop, key.step)
#     <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/numeric.py?line=233'>234</a> return super()._convert_slice_indexer(key, kind=kind)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6515'>6516</a> """
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6516'>6517</a> Compute the slice indexer for input labels and step.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6517'>6518</a>
#    (...)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6554'>6555</a> slice(1, 3, None)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6555'>6556</a> """
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6556'>6557</a> self._deprecated_arg(kind, "kind", "slice_indexer")
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6558'>6559</a> start_slice, end_slice = self.slice_locs(start, end, step=step)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6560'>6561</a> # return a slice
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6561'>6562</a> if not is_scalar(start_slice):
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6773, in Index.slice_locs(self, start, end, step, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6770'>6771</a> end_slice = None
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6771'>6772</a> if end is not None:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6772'>6773</a>     end_slice = self.get_slice_bound(end, "right")
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6773'>6774</a> if end_slice is None:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6774'>6775</a>     end_slice = len(self)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6686, in Index.get_slice_bound(self, label, side, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6682'>6683</a>         return self._searchsorted_monotonic(label, side)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6683'>6684</a>     except ValueError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6684'>6685</a>         # raise the original KeyError
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6685'>6686</a>         raise err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6687'>6688</a> if isinstance(slc, np.ndarray):
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6688'>6689</a>     # get_loc may return a boolean array, which
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6689'>6690</a>     # is OK as long as they are representable by a slice.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6690'>6691</a>     assert is_bool_dtype(slc.dtype)
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:6680, in Index.get_slice_bound(self, label, side, kind)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6677'>6678</a> # we need to look up the label
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6678'>6679</a> try:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6679'>6680</a>     slc = self.get_loc(label)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6680'>6681</a> except KeyError as err:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=6681'>6682</a>     try:
#
# File c:\Users\pcnba\mambaforge\envs\Microfluidics_Pipe_highest\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a> except KeyError as err:
# -> <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3803'>3804</a>     raise KeyError(key) from err
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3804'>3805</a> except TypeError:
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3805'>3806</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3806'>3807</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3807'>3808</a>     #  the TypeError.
#    <a href='file:///c%3A/Users/pcnba/mambaforge/envs/Microfluidics_Pipe_highest/lib/site-packages/pandas/core/indexes/base.py?line=3808'>3809</a>     self._check_indexing_error(key)
#
# KeyError: -5

# %%
Localization_information
# Out:
#            Unnamed: 0 Protein  Frame_x         Cell_Barcode  \
# 0.0               0.0    YOF1      1.0  d0222r2p740200c0007
# 1.0               1.0    YOF1      1.0  d0222r2p740200c0010
# 2.0               2.0    YOF1      1.0  d0222r2p740200c0013
# 3.0               3.0    YOF1      1.0  d0222r2p740200c0016
# 4.0               4.0    YOF1      1.0  d0222r2p740200c0020
# ...               ...     ...      ...                  ...
# 7571823.0     13840.0   PPH22     48.0  d0214r2p090200c0321
# 7571824.0     13841.0   PPH22     48.0  d0214r2p090200c0325
# 7571825.0     13842.0   PPH22     48.0  d0214r2p090200c0328
# 7571826.0     13843.0   PPH22     48.0  d0214r2p090200c0329
# 7571827.0     13844.0   PPH22     48.0  d0214r2p090200c0335
#
#                        ImageID   Date         Unique_Frame  \
# 0.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 1.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 2.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 3.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# 4.0        d0222r2p740200f0001  d0222  d0222r2p740200f0001
# ...                        ...    ...                  ...
# 7571823.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571824.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571825.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571826.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
# 7571827.0  d0214r2p090200f0048  d0214  d0214r2p090200f0048
#
#            x90thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.116923
# 1.0                                   1.130081
# 2.0                                   1.112000
# 3.0                                   1.123188
# 4.0                                   1.133858
# ...                                        ...
# 7571823.0                             1.107692
# 7571824.0                             1.100000
# 7571825.0                             1.093023
# 7571826.0                             1.100000
# 7571827.0                             1.099237
#
#            x95thPercentile_norm_OBJ_Median_GFP  \
# 0.0                                   1.146154
# 1.0                                   1.178862
# 2.0                                   1.144000
# 3.0                                   1.166667
# 4.0                                   1.151181
# ...                                        ...
# 7571823.0                             1.146154
# 7571824.0                             1.132308
# 7571825.0                             1.124031
# 7571826.0                             1.130769
# 7571827.0                             1.129771
#
#            x99thPercentile_norm_OBJ_Median_GFP  ...  count  Abundance  \
# 0.0                                   1.223077  ...  127.0   4.867534
# 1.0                                   1.264146  ...  127.0   4.812184
# 2.0                                   1.181520  ...  127.0   4.828314
# 3.0                                   1.246377  ...  127.0   4.927254
# 4.0                                   1.251969  ...  127.0   4.844187
# ...                                        ...  ...    ...        ...
# 7571823.0                             1.192308  ...  159.0   4.867534
# 7571824.0                             1.191077  ...  159.0   4.867534
# 7571825.0                             1.178295  ...  159.0   4.859812
# 7571826.0                             1.214000  ...  159.0   4.867534
# 7571827.0                             1.175344  ...  159.0   4.875197
#
#            z_score_Loc  z_score_Abund  Pearson_coeff_Loc_Abund  \
# 0.0          -0.799651      -0.620910                 0.125106
# 1.0          -0.193858      -1.030582                 0.125106
# 2.0           0.349437      -0.911201                 0.125106
# 3.0          -0.661603      -0.178900                 0.125106
# 4.0          -0.514413      -0.793715                 0.125106
# ...                ...            ...                      ...
# 7571823.0    -0.089417       0.014743                 0.052237
# 7571824.0    -0.528462       0.014743                 0.052237
# 7571825.0     0.051342      -0.224311                 0.052237
# 7571826.0    -0.421331       0.014743                 0.052237
# 7571827.0    -0.351662       0.251966                 0.052237
#
#            Signif_corr_Loc_Abund  Systematic ORF  Location_simplfied  \
# 0.0                     0.161081            None                None
# 1.0                     0.161081            None                None
# 2.0                     0.161081            None                None
# 3.0                     0.161081            None                None
# 4.0                     0.161081            None                None
# ...                          ...             ...                 ...
# 7571823.0               0.513151            None                None
# 7571824.0               0.513151            None                None
# 7571825.0               0.513151            None                None
# 7571826.0               0.513151            None                None
# 7571827.0               0.513151            None                None
#
#                        Strain_frame  Time_post_treatment
# 0.0         d0222r2p740200f0001YOF1               -195.0
# 1.0         d0222r2p740200f0001YOF1               -195.0
# 2.0         d0222r2p740200f0001YOF1               -195.0
# 3.0         d0222r2p740200f0001YOF1               -195.0
# 4.0         d0222r2p740200f0001YOF1               -195.0
# ...                             ...                  ...
# 7571823.0  d0214r2p090200f0048PPH22                172.5
# 7571824.0  d0214r2p090200f0048PPH22                172.5
# 7571825.0  d0214r2p090200f0048PPH22                172.5
# 7571826.0  d0214r2p090200f0048PPH22                172.5
# 7571827.0  d0214r2p090200f0048PPH22                172.5
#
# [7571828 rows x 92 columns]

# %%
 Localization_information['ImageID'].apply(lambda x: x[:-5]) + Localization_information['Protein']
# Out:
# 0.0           d0222r2p740200YOF1
# 1.0           d0222r2p740200YOF1
# 2.0           d0222r2p740200YOF1
# 3.0           d0222r2p740200YOF1
# 4.0           d0222r2p740200YOF1
#                     ...
# 7571823.0    d0214r2p090200PPH22
# 7571824.0    d0214r2p090200PPH22
# 7571825.0    d0214r2p090200PPH22
# 7571826.0    d0214r2p090200PPH22
# 7571827.0    d0214r2p090200PPH22
# Length: 7571828, dtype: object

# %%
 Localization_information['ImageID'].apply(lambda x: x[-5:]) + Localization_information['Protein']
# Out:
# 0.0           f0001YOF1
# 1.0           f0001YOF1
# 2.0           f0001YOF1
# 3.0           f0001YOF1
# 4.0           f0001YOF1
#                 ...
# 7571823.0    f0048PPH22
# 7571824.0    f0048PPH22
# 7571825.0    f0048PPH22
# 7571826.0    f0048PPH22
# 7571827.0    f0048PPH22
# Length: 7571828, dtype: object

# %%
#* Group cells by the strain frame
Localization_information['Strain_frame'] = Localization_information['ImageID'].apply(lambda x: x[-5:]) + Localization_information['Protein']

# %%
try: Localization_information['Time_post_treatment']
except KeyError:
	Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Frames_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))

# %%
Localization_information['Time_post_treatment'] = pd.Series(Localization_information['Frames_post_treatment']).apply(lambda x: convert_frames_time(x, frame_gap = 7.5))

# %%
zero_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 0].groupby('Strain_frame')['Abundance'].agg('mean')
two_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 120].groupby('Strain_frame')['Abundance'].agg('mean')
four_hrs_mean = Localization_information.loc[Localization_information['Time_post_treatment'] == 240].groupby('Strain_frame')['Abundance'].agg('mean')

# %%
zero_hrs_mean
# Out:
# Strain_frame
# f0015DDC2d013r1    4.861642
# f0015MSH3          4.842075
# f0015YLR297W       4.844399
# f0023ACE2          4.849184
# f0023APC1          4.877501
#                      ...
# f0031YDR132C       4.869239
# f0031YKU70         4.868300
# f0031YKU80         4.856213
# f0031YML011C       4.779357
# f0031YML108W       4.830486
# Name: Abundance, Length: 138, dtype: float64

# %%
zero_hrs_mean
# Out:
# Strain_frame
# f0015DDC2d013r1    4.861642
# f0015MSH3          4.842075
# f0015YLR297W       4.844399
# f0023ACE2          4.849184
# f0023APC1          4.877501
#                      ...
# f0031YDR132C       4.869239
# f0031YKU70         4.868300
# f0031YKU80         4.856213
# f0031YML011C       4.779357
# f0031YML108W       4.830486
# Name: Abundance, Length: 138, dtype: float64

# %%
zero_hrs_mean
# Out:
# Strain_frame
# f0015DDC2d013r1    4.861642
# f0015MSH3          4.842075
# f0015YLR297W       4.844399
# f0023ACE2          4.849184
# f0023APC1          4.877501
#                      ...
# f0031YDR132C       4.869239
# f0031YKU70         4.868300
# f0031YKU80         4.856213
# f0031YML011C       4.779357
# f0031YML108W       4.830486
# Name: Abundance, Length: 138, dtype: float64
